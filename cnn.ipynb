# %%
import numpy as np 
import pandas as pd 
import os
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
import sys

# %%
batch_size = 40
img_height = 200
img_width = 200

# %%
training_ds = tf.keras.preprocessing.image_dataset_from_directory(
    './data',
    validation_split=0.2,
    subset= "training",
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size

)
# Out:
# Found 7553 files belonging to 2 classes.
# Using 6043 files for training.

# %%
## loading testing data
testing_ds = tf.keras.preprocessing.image_dataset_from_directory(
'./data',
    validation_split=0.2,
    subset= "validation",
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size

)
# Out:
# Found 7553 files belonging to 2 classes.
# Using 1510 files for validation.

# %%
class_names = training_ds.class_names
class_names
# Out:
# ['with_mask', 'without_mask']

# %%
plt.figure(figsize=(10, 10))
for images, labels in training_ds.take(1):
  for i in range(12):
    ax = plt.subplot(3, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.grid(True)

# %%
## Configuring dataset for performance
AUTOTUNE = tf.data.experimental.AUTOTUNE
training_ds = training_ds.cache().prefetch(buffer_size=AUTOTUNE)
testing_ds = testing_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

## lets define our CNN
MyCnn = tf.keras.models.Sequential([
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, activation='relu'),
  layers.MaxPooling2D(),
  # Some thing I realised just
  # using flatten layer will 
  # increase the size of your
  # model, hence use
  # Global avg Pooling 
  # instead
  # layers.Flatten(),
  layers.GlobalAveragePooling2D(),
  layers.Dense(256, activation='relu'),
  layers.Dense(2, activation= 'softmax')
])
# Out:
# Num GPUs Available:  1

# %%
MyCnn.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
retVal = MyCnn.fit(training_ds, validation_data= testing_ds, epochs = 15)
# Out:
# Epoch 1/15
# 152/152 [==============================] - 9s 44ms/step - loss: 0.5870 - accuracy: 0.6891 - val_loss: 0.5598 - val_accuracy: 0.6980
# Epoch 2/15
# 152/152 [==============================] - 5s 31ms/step - loss: 0.5325 - accuracy: 0.7395 - val_loss: 0.4963 - val_accuracy: 0.7543
# Epoch 3/15
# 152/152 [==============================] - 5s 31ms/step - loss: 0.5130 - accuracy: 0.7513 - val_loss: 0.4820 - val_accuracy: 0.7815
# Epoch 4/15
# 152/152 [==============================] - 5s 31ms/step - loss: 0.4885 - accuracy: 0.7680 - val_loss: 0.4360 - val_accuracy: 0.7967
# Epoch 5/15
# 152/152 [==============================] - 5s 31ms/step - loss: 0.4390 - accuracy: 0.7976 - val_loss: 0.3973 - val_accuracy: 0.8358
# Epoch 6/15
# 152/152 [==============================] - 5s 31ms/step - loss: 0.3818 - accuracy: 0.8360 - val_loss: 0.3249 - val_accuracy: 0.8781
# Epoch 7/15
# 152/152 [==============================] - 5s 31ms/step - loss: 0.3443 - accuracy: 0.8640 - val_loss: 0.2791 - val_accuracy: 0.8993
# Epoch 8/15
# 152/152 [==============================] - 5s 31ms/step - loss: 0.3141 - accuracy: 0.8756 - val_loss: 0.2590 - val_accuracy: 0.9053
# Epoch 9/15
# 152/152 [==============================] - 5s 31ms/step - loss: 0.2892 - accuracy: 0.8881 - val_loss: 0.2508 - val_accuracy: 0.9086
# Epoch 10/15
# 152/152 [==============================] - 5s 31ms/step - loss: 0.2757 - accuracy: 0.8981 - val_loss: 0.2340 - val_accuracy: 0.9132
# Epoch 11/15
# 152/152 [==============================] - 5s 31ms/step - loss: 0.2558 - accuracy: 0.9063 - val_loss: 0.2128 - val_accuracy: 0.9238
# Epoch 12/15
# 152/152 [==============================] - 5s 31ms/step - loss: 0.2409 - accuracy: 0.9103 - val_loss: 0.2062 - val_accuracy: 0.9285
# Epoch 13/15
# 152/152 [==============================] - 5s 31ms/step - loss: 0.2288 - accuracy: 0.9178 - val_loss: 0.1941 - val_accuracy: 0.9318
# Epoch 14/15
# 152/152 [==============================] - 5s 31ms/step - loss: 0.2175 - accuracy: 0.9221 - val_loss: 0.1843 - val_accuracy: 0.9325
# Epoch 15/15
# 152/152 [==============================] - 5s 31ms/step - loss: 0.2032 - accuracy: 0.9242 - val_loss: 0.1787 - val_accuracy: 0.9377

# %%
model_json = MyCnn.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
MyCnn.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
MyCnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 200, 200, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 198, 198, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 99, 99, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 97, 97, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 46, 46, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 23, 23, 128)       0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               33024
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 126,786
# Trainable params: 126,786
# Non-trainable params: 0
# _________________________________________________________________
